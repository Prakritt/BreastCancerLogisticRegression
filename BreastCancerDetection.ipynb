# %%
##IMPOR TTHE LIBRARIES 
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#Output Feature 
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
print(df.shape)
# Out:
# (569, 33)

# %%
print(df.isnull().sum())
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.drop("Unnamed: 32", axis =1 , inplace = True)

# %%
df.corr(numeric_only=True)
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
##Handling Categorial Values
df['diagnosis'] = df['diagnosis'].map({'M' : 1, 'B' : 0})

# %%
df['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
df.shape
# Out:
# (569, 32)

# %%
##Separate Input and Output Variables
X = df.drop("diagnosis", axis = 1 )
y = df["diagnosis"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (569, 31)
# (569,)

# %%
##SPLITTING INTO TRAINING AND TESTING 
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (426, 31)
# (143, 31)

# %%
X_train
# Out:
#             id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 287       8913       12.890         13.12           81.89      515.9
# 512     915691       13.400         20.52           88.64      556.7
# 402     904689       12.960         18.29           84.18      525.2
# 446    9110732       17.750         28.03          117.30      981.6
# 210  881046502       20.580         22.14          134.70     1290.0
# ..         ...          ...           ...             ...        ...
# 71      859711        8.888         14.64           58.79      244.0
# 106     863031       11.640         18.33           75.17      412.5
# 270    8910721       14.290         16.82           90.30      632.6
# 435     908489       13.980         19.62           91.12      599.5
# 102     862965       12.180         20.52           77.22      458.7
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
##SCALING THE DATASET 
from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()

# %%
standardScaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = standardScaler.transform(X_train)

# %%
X_test = standardScaler.transform(X_test)

# %%
print(X_train)
# Out:
# [[-0.23995002 -0.34913849 -1.43851335 ... -0.91671059 -0.92508585
#   -0.80841115]
#  [-0.23295727 -0.20468665  0.31264011 ...  1.43655962  1.14955889
#    1.56911143]
#  [-0.23304211 -0.32931176 -0.21507235 ... -0.7237126   0.53496977
#   -0.61934827]
#  ...
#  [-0.17130241  0.04739597 -0.56293662 ... -1.23262438 -0.68282718
#   -1.261137  ]
#  [-0.23301281 -0.04040808  0.09966199 ...  1.08847951  0.48944465
#    1.26159953]
#  [-0.23336387 -0.5502381   0.31264011 ... -0.59582424 -0.29911546
#   -0.82948141]]

# %%
##IMPORT HTE LOGISTIC REGRESSION MODEL
from sklearn.linear_model import LogisticRegression
logisticRegression = LogisticRegression()

# %%
logisticRegression.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logisticRegression.predict(X_test)

# %%
##SHOW THE ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9790209790209791

# %%
test_data = (-0.17283264,  0.23999843,  0.13279192,  0.14891207,  0.0990963 ,
       -0.81309388, -0.95289821, -0.86603332, -0.7497801 , -1.06486419,
       -1.37790225, -0.76209638, -0.26241768, -0.75318008, -0.48975265,
       -1.10078505, -0.9538591 , -0.80110157, -0.86283111, -0.15644404,
       -0.84367003, -0.04854679,  0.05201448, -0.13884173, -0.16228105,
       -1.15112806, -0.99034738, -0.95702087, -0.85641814, -0.37715852,
       -1.28106833)

# %%
input_text = np.asarray(test_data).reshape(1,-1)

# %%
prediction = logisticRegression.predict(input_text)

# %%
result = "Malignant" if prediction[0] == "1" else "Non malignant"

# %%
print(result)
# Out:
# Non malignant
